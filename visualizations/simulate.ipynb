# %%
import matplotlib.pyplot as plt
import importlib

import coup.player as player
import visualizations.rl_player as rl_player
import visualizations.game as game
importlib.reload(player)
importlib.reload(rl_player)
importlib.reload(game)
from coup.player import *
from visualizations.rl_player import *
from visualizations.game import *

# %%
NUM_GAMES = 10000

def run_simulation(players, shuffle_turn_order=True, num_games=NUM_GAMES, turn_limit=50):
    winners = []
    for _ in range(num_games):
        if shuffle_turn_order:
            random.shuffle(players)
        game = Game(players)
        turn_count = 0
        while len(game.game_state['players']) > 1 and turn_count < turn_limit:
            game.simulate_turn()
            turn_count += 1
        if turn_count == turn_limit:
            winner = 'draw'
        else:
            winner = game.game_state['players'][0].name
        winners.append(winner)
    return winners

def plot_winners(winners, player_types, title):
    player_type_wins = {p_type : 0 for p_type in player_types.values()}
    for p_type in player_type_wins.keys():
        player_type_wins[p_type] = len([winner for winner in winners if player_types[winner] == p_type])
    plt.figure()
    p1 = plt.bar(player_type_wins.keys(), player_type_wins.values(), color='forestgreen')
    for rect1 in p1:
        percent_wins = round(rect1.get_height() / len(winners) * 100, 4)
        height = rect1.get_height()
        plt.annotate( "{}%".format(percent_wins),(rect1.get_x() + rect1.get_width()/2, height / 2),ha="center",va="bottom",fontsize=15)
    plt.title(title)
    plt.show()

# %%
players = [Player('random_player', RANDOM_FUNCS), Player('truth_player', TRUTH_FUNCS)]
player_types = {'random_player': 'random', 'truth_player': 'truth'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. truth wins")

# %%
players = [Player('truth_player', TRUTH_FUNCS), Player('greedy_player', GREEDY_FUNCS)]
player_types = {'truth_player': 'truth', 'greedy_player': 'greedy'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "truth v.s. greedy wins")

# %%
players = [Player('random_player', RANDOM_FUNCS), Player('greedy_player', GREEDY_FUNCS)]
player_types = {'random_player': 'random', 'greedy_player': 'greedy'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. greedy wins")

# %%
players = [Player('random_player', RANDOM_FUNCS), Player('truth_player', TRUTH_FUNCS), Player('greedy_player', GREEDY_FUNCS)]
player_types = {'random_player': 'random', 'truth_player': 'truth', 'greedy_player': 'greedy'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. truth v.s. greedy wins")

# %%
players = [Player('random_player1', RANDOM_FUNCS), Player('random_player2', RANDOM_FUNCS), Player('truth_player', TRUTH_FUNCS), Player('greedy_player', GREEDY_FUNCS)]
player_types = {'random_player1': 'random1', 'random_player2': 'random2', 'truth_player': 'truth', 'greedy_player': 'greedy'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. random v.s. truth v.s. greedy wins")

# %%
players = [Player('random_player', RANDOM_FUNCS), Player('truth_player1', TRUTH_FUNCS), Player('truth_player2', TRUTH_FUNCS), Player('greedy_player', GREEDY_FUNCS)]
player_types = {'random_player': 'random', 'truth_player1': 'truth1', 'truth_player2': 'truth2', 'greedy_player': 'greedy'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. truth v.s. truth v.s. greedy wins")

# %%
players = [Player('random_player', RANDOM_FUNCS), Player('truth_player', TRUTH_FUNCS), Player('greedy_player1', GREEDY_FUNCS), Player('greedy_player2', GREEDY_FUNCS)]
player_types = {'random_player': 'random', 'truth_player': 'truth', 'greedy_player1': 'greedy1', 'greedy_player2': 'greedy2'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. truth v.s. greedy v.s. greedy wins")

# %%
players = [Player('truth_player1', TRUTH_FUNCS), Player('truth_player2', TRUTH_FUNCS), Player('greedy_player1', GREEDY_FUNCS), Player('greedy_player2', GREEDY_FUNCS)]
player_types = {'truth_player1': 'truth1', 'truth_player2': 'truth2', 'greedy_player1': 'greedy1', 'greedy_player2': 'greedy2'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "truth v.s. truth v.s. greedy v.s. greedy wins")

# %%
players = [Player('truth_player1', TRUTH_FUNCS), Player('truth_player2', TRUTH_FUNCS), Player('truth_player3', TRUTH_FUNCS), Player('greedy_player', GREEDY_FUNCS)]
player_types = {'truth_player1': 'truth1', 'truth_player2': 'truth2', 'truth_player3': 'truth3', 'greedy_player': 'greedy'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "truth v.s. truth v.s. truth v.s. greedy wins")

# %%
players = [Player('random_player', RANDOM_FUNCS), Player('income_player', INCOME_FUNCS)]
player_types = {'random_player': 'random', 'income_player': 'income'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. income wins")

# %%
players = [Player('truth_player', TRUTH_FUNCS), Player('income_player', INCOME_FUNCS)]
player_types = {'truth_player': 'truth', 'income_player': 'income'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "truth v.s. income wins")

# %%
players = [Player('greedy_player', GREEDY_FUNCS), Player('income_player', INCOME_FUNCS)]
player_types = {'greedy_player': 'greedy', 'income_player': 'income'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "greedy v.s. income wins")

# %%
players = [Player('random_player', RANDOM_FUNCS), Player('truth_player', TRUTH_FUNCS), Player('greedy_player', GREEDY_FUNCS), Player('income_player', INCOME_FUNCS)]
player_types = {'random_player': 'random', 'truth_player': 'truth', 'greedy_player': 'greedy', 'income_player': 'income'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. truth v.s. greedy v.s. income wins")

# %%
players = [Player('random_player', RANDOM_FUNCS), Player('truth_player1', TRUTH_FUNCS), Player('truth_player2', TRUTH_FUNCS), Player('income_player', INCOME_FUNCS)]
player_types = {'random_player': 'random', 'truth_player1': 'truth1', 'truth_player2': 'truth2', 'income_player': 'income'}
winners = run_simulation(players, turn_limit=1000)
plot_winners(winners, player_types, "random v.s. truth v.s. truth v.s. income wins")

# %%
def plot_lies(agent):
    """
    Display the total lie% and the relative lie% for each action.
    """
    actions = agent.list_of_actions
    lies = agent.did_action_lie
    lies = [lie for idx, lie in enumerate(lies) if actions[idx][2] != 'Income' and actions[idx][2] != 'Foreign Aid' and actions[idx][2] != 'Coup']

    total_lie_freq = round(sum(lies) / len(lies), 2)

    action_types = set([a[2] for a in actions])
    type_lies = {}
    type_lie_freq = {'Overall': 0, 'Tax': 0, 'Exchange': 0, 'Steal': 0, 'Assassinate': 0}
    type_lie_freq['Overall'] = total_lie_freq
    for type in action_types:
        type_lies[type] = [lie for idx, lie in enumerate(lies) if actions[idx][2] == type]
        if type != 'Income' and type != 'Foreign Aid' and type != 'Coup' and len(type_lies[type]) > 0:
            type_lie_freq[type] = round(sum(type_lies[type]) / len(type_lies[type]), 2)
    plt.figure()
    p1 = plt.bar(type_lie_freq.keys(), type_lie_freq.values(), color=['indianred', 'plum', 'lightgreen', 'cornflowerblue', 'lightslategray'])
    for rect1 in p1:
        height = rect1.get_height()
        plt.annotate( "{}%".format(rect1.get_height()),(rect1.get_x() + rect1.get_width()/2, height / 2),ha="center",va="bottom",fontsize=15)
    plt.title('Lie frequency of {0}'.format(agent.name))
    plt.show()


def plot_action_types(agent):
    """
    Display the frequency of actions taken by the agent.
    """
    actions = agent.list_of_actions
    action_types = set([a[2] for a in actions])
    action_freq = {'Tax': 0, 'Exchange': 0, 'Income': 0, 'Assassinate': 0, 'Steal': 0, 'Foreign Aid': 0, 'Coup': 0}
    for type in action_types:
        action_freq[type] = round(len([a for a in actions if a[2] == type]) / len(actions), 3)
    fig = plt.figure()
    fig.set_figwidth(10)
    p1 = plt.bar(action_freq.keys(), action_freq.values(), color=['plum', 'lightgreen', 'gainsboro', 'lightslategray', 'cornflowerblue', 'gainsboro', 'gainsboro'])
    for rect1 in p1:
        height = rect1.get_height()
        plt.annotate( "{}%".format(rect1.get_height()),(rect1.get_x() + rect1.get_width()/2, height / 2),ha="center",va="bottom",fontsize=15)
    plt.title('Action frequency of {0}'.format(agent.name))
    plt.show()

# %%
rl_decision, agent = get_rl_decision(load_model(4, 'models/4-1000-random,greedy,truth'), '4-1000-random,greedy,truth')
RL_FUNCS = {'decision_fn': rl_decision, 'block_fn': income_block, 'dispose_fn': random_dispose, 'keep_fn': random_keep}

players = [Player('4-1000-random,greedy,truth', RL_FUNCS), Player('random_player', RANDOM_FUNCS), Player('greedy_player', GREEDY_FUNCS), Player('truth_player', TRUTH_FUNCS)]
player_types = {'4-1000-random,greedy,truth': 'rl', 'random_player': 'random', 'greedy_player': 'greedy', 'truth_player': 'truth', 'draw': 'draw'}
winners = run_simulation(players, shuffle_turn_order=False)
plot_winners(winners, player_types, "rl4-1000-random,greedy,truth v.s. random v.s. greedy v.s. truth")
plot_action_types(agent)
plot_lies(agent)

# %%
rl_decision, agent = get_rl_decision(load_model(2, 'models/2-5000-income'), '2-5000-income')
RL_FUNCS = {'decision_fn': rl_decision, 'block_fn': income_block, 'dispose_fn': random_dispose, 'keep_fn': random_keep}

players = [Player('2-5000-income', RL_FUNCS), Player('income_player', INCOME_FUNCS)]
player_types = {'2-5000-income': 'rl', 'income_player': 'income', 'draw': 'draw'}
winners = run_simulation(players, shuffle_turn_order=False)
plot_winners(winners, player_types, "rl2-5000-income v.s. income")
plot_action_types(agent)
plot_lies(agent)

# %%
rl_decision, agent = get_rl_decision(load_model(5, 'models/5-10000-random,greedy,income,truth'), '5-10000-random,greedy,income,truth')
RL_FUNCS = {'decision_fn': rl_decision, 'block_fn': income_block, 'dispose_fn': random_dispose, 'keep_fn': random_keep}

players = [Player('5-10000-random,greedy,income,truth', RL_FUNCS), Player('random_player', RANDOM_FUNCS), Player('greedy_player', GREEDY_FUNCS), Player('income_player', INCOME_FUNCS), Player('truth_player', TRUTH_FUNCS)]
player_types = {'5-10000-random,greedy,income,truth': 'rl', 'random_player': 'random', 'greedy_player': 'greedy', 'income_player': 'income', 'truth_player': 'truth', 'draw': 'draw'}
winners = run_simulation(players, shuffle_turn_order=False, turn_limit=500)
plot_winners(winners, player_types, "rl5-10000-random,greedy,income,truth v.s. random v.s. greedy v.s. income v.s. truth")
plot_action_types(agent)
plot_lies(agent)

# %%
rl_decision, agent = get_rl_decision(load_model(2, 'models/2-2000-truth'), '2-2000-truth')
RL_FUNCS = {'decision_fn': rl_decision, 'block_fn': income_block, 'dispose_fn': random_dispose, 'keep_fn': random_keep}

players = [Player('2-2000-truth', RL_FUNCS), Player('greedy_player', GREEDY_FUNCS)]
player_types = {'2-2000-truth': 'rl', 'greedy_player': 'greedy', 'draw': 'draw'}
winners = run_simulation(players, shuffle_turn_order=False)
plot_winners(winners, player_types, "rl2-2000-truth v.s. greedy")
plot_action_types(agent)
plot_lies(agent)

# %%
rl_decision, agent = get_rl_decision(load_model(4, 'models/4-7500-truth,truth,income'), '4-7500-truth,truth,income')
RL_FUNCS = {'decision_fn': rl_decision, 'block_fn': income_block, 'dispose_fn': random_dispose, 'keep_fn': random_keep}

players = [Player('4-7500-truth,truth,income', RL_FUNCS), Player('truth_player1', TRUTH_FUNCS), Player('truth_player2', TRUTH_FUNCS), Player('truth_player3', TRUTH_FUNCS)]
player_types = {'4-7500-truth,truth,income': 'rl', 'truth_player1': 'truth1', 'truth_player2': 'truth2', 'truth_player3': 'truth3', 'draw': 'draw'}
winners = run_simulation(players, shuffle_turn_order=False)
plot_winners(winners, player_types, "rl4-7500-truth,truth,income v.s. truth v.s. truth v.s. truth")
plot_action_types(agent)
plot_lies(agent)

# %%
rl_decision, agent = get_rl_decision(load_model(6, 'models/6-5000-random,random,random,random,random'), '6-5000-random,random,random,random,random')
RL_FUNCS = {'decision_fn': rl_decision, 'block_fn': income_block, 'dispose_fn': random_dispose, 'keep_fn': random_keep}

players = [Player('6-5000-random,random,random,random,random', RL_FUNCS), Player('income_player', INCOME_FUNCS), Player('random_player1', RANDOM_FUNCS), Player('random_player2', RANDOM_FUNCS), Player('random_player3', RANDOM_FUNCS), Player('random_player4', RANDOM_FUNCS)]
player_types = {'6-5000-random,random,random,random,random': 'rl', 'income_player': 'income', 'random_player1': 'random1', 'random_player2': 'random2', 'random_player3': 'random3', 'random_player4': 'random4','draw': 'draw'}
winners = run_simulation(players, shuffle_turn_order=False, turn_limit=600)
plot_winners(winners, player_types, "6-5000-random,random,random,random,random v.s. income v.s. random v.s. random v.s. random v.s. random ")
plot_action_types(agent)
plot_lies(agent)
